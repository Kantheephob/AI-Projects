# %%
# ==============================================
# Mini Project : Association Rule Mining ตัวอย่างสำหรับคำถามข้อ 3
# 1) ขั้นตอน Support + Confidence ให้กฎจำนวนมาก แต่มี spurious rules
# 2) การใช้ Lift ช่วยกำจัดกฎที่เกิดจาก popularity ของ item
# 3) การใช้ p-value ช่วยยืนยันว่าความสัมพันธ์มีนัยสำคัญทางสถิติ
# ส่งผลให้จำนวนกฎลดลง แต่มีความน่าเชื่อถือมากขึ้น
# ==============================================

import pandas as pd
import numpy as np
from itertools import combinations
from scipy.stats import chi2_contingency

pd.set_option('display.max_columns', None)   # แสดงทุก column
pd.set_option('display.width', 1000)         # กำหนดความกว้างหน้าจอ
pd.set_option('display.expand_frame_repr', False)  # ไม่ wrap ข้อความในบรรทัด

# ==============================================
# 1) LOAD DATA
# ==============================================

url = "https://raw.githubusercontent.com/pakornlee/ml_example/23665225ce5781e8ea782e18829e6108a5a4c92f/transactions_1000_onehot.csv"
df = pd.read_csv(url)
df.columns = df.columns.str.strip()
df = df.astype(int)

min_sup = 0.05
min_conf = 0.3
top_n = 30

# ==============================================
# 2) COMPACT (Bitset + Pruning + Top-N)
# ==============================================

def run_compact(df, min_sup, max_k=6, top_n=30):
    total = len(df)

    bit_data = {}
    for col in df.columns:
        bitstring = ''.join(df[col].astype(str))
        bit_data[frozenset([col])] = int(bitstring, 2)

    L = {1: {}}

    # L1
    for itemset, bit in bit_data.items():
        sup = bin(bit).count('1') / total
        if sup >= min_sup:
            L[1][itemset] = (bit, sup)

    # Top-N
    L[1] = dict(sorted(L[1].items(), key=lambda x: x[1][1], reverse=True)[:top_n])

    # Lk
    for k in range(2, max_k + 1):
        L[k] = {}
        prev = list(L[k-1].keys())

        candidates = []
        for i in range(len(prev)):
            for j in range(i+1, len(prev)):
                union = prev[i] | prev[j]
                if len(union) == k:
                    candidates.append(union)

        # prune
        for c in candidates:
            if all((c - frozenset([x])) in L[k-1] for x in c):
                items = list(c)
                bit = bit_data[frozenset([items[0]])]

                for item in items[1:]:
                    bit &= bit_data[frozenset([item])]

                sup = bin(bit).count('1') / total
                if sup >= min_sup:
                    L[k][c] = (bit, sup)

        if len(L[k]) == 0:
            break

        L[k] = dict(sorted(L[k].items(), key=lambda x: x[1][1], reverse=True)[:top_n])

    results = {}
    for k in L:
        for itemset, (_, sup) in L[k].items():
            results[itemset] = sup

    return results

# ==============================================
# 3) GENERATE ASSOCIATION RULES
# ==============================================

def generate_rules(freq_itemsets, df):
    rules = []
    total = len(df)

    for itemset, sup in freq_itemsets.items():
        if len(itemset) < 2:
            continue

        for i in range(1, len(itemset)):
            for antecedent in combinations(itemset, i):
                antecedent = frozenset(antecedent)
                consequent = itemset - antecedent

                sup_X = freq_itemsets.get(antecedent, 0)
                sup_Y = freq_itemsets.get(consequent, 0)

                if sup_X == 0 or sup_Y == 0:
                    continue

                confidence = sup / sup_X
                lift = confidence / sup_Y

                # chi-square → p-value
                X = df[list(antecedent)].all(axis=1)
                Y = df[list(consequent)].all(axis=1)

                n11 = ((X) & (Y)).sum()
                n10 = ((X) & (~Y)).sum()
                n01 = ((~X) & (Y)).sum()
                n00 = ((~X) & (~Y)).sum()

                table = [[n11, n10], [n01, n00]]

                try:
                    chi2, p, _, _ = chi2_contingency(table)
                except:
                    p = 1

                rules.append({
                    'antecedent': antecedent,
                    'consequent': consequent,
                    'support': sup,
                    'confidence': confidence,
                    'lift': lift,
                    'p_value': p
                })

    return pd.DataFrame(rules)

# ==============================================
# 4) RUN
# ==============================================

freq_itemsets = run_compact(df, min_sup)
rules = generate_rules(freq_itemsets, df)

print("All Rules:", len(rules))
print(rules)

# ==============================================
# 5) FILTER 3 APPROACHES
# ==============================================

# (A) Support + Confidence
rules_sc = rules[
    (rules['support'] >= min_sup) &
    (rules['confidence'] >= min_conf)
].sort_values(['confidence', 'support'], ascending=False)

# (B) + Lift
rules_scl = rules_sc[
    (rules_sc['lift'] > 1)
].sort_values(['lift', 'confidence'], ascending=False)

# (C) + p-value
rules_sclp = rules_scl[
    (rules_scl['p_value'] < 0.05)
].sort_values(['p_value', 'lift'], ascending=[True, False])

# ==============================================
# 6) SHOW RESULT
# ==============================================

print("\n===== Basic Rules (A) = Support + Confidence =====")
print(rules_sc.to_string(index=False))

print("\n===== Strong / Interesting Rules (B) = (A) + Lift =====")
print(rules_scl.to_string(index=False))

print("\n===== Significant Rules (C) = (B) + p-value =====")
print(rules_sclp.to_string(index=False))

print("\nCOUNT COMPARISON")
print(f"(A) Support & Cofidence : {len(rules_sc)} rules")
print(f"(B) Support, Confidence & Lift : {len(rules_scl)} rules")
print(f"(C) Support, Confidence, Lift & p-value : {len(rules_sclp)} rules")

# ==============================================
# 7) IDENTIFY SPURIOUS RULES
# ==============================================

# (1) ถูกตัดออกในขั้นตอน B (Lift <= 1)
spurious_lift = rules_sc[
    (rules_sc['lift'] <= 1)
].copy()

spurious_lift['reason'] = '     Low Lift (<=1) → Independent'

# (2) ถูกตัดออกในขั้นตอน C (p-value >= 0.05)
spurious_p = rules_scl[
    (rules_scl['p_value'] >= 0.05)
].copy()

spurious_p['reason'] = '     High p-value (>=0.05) → Not Significant'

# ==============================================
# 8) SHOW SPURIOUS RULES
# ==============================================

print("\n🔴 Spurious Rules removed in Step B (Lift filter)")
print(spurious_lift.sort_values(['lift'], ascending=False).head(10).to_string(index=False))

print("\n🔴 Spurious Rules removed in Step C (p-value filter)")
print(spurious_p.sort_values(['p_value'], ascending=True).head(10).to_string(index=False))

# ==============================================
# 9) COMBINE SPURIOUS RULES FROM B AND C
# ==============================================

spurious_all = pd.concat([spurious_lift, spurious_p])

print("\n===== SUMMARY OF SPURIOUS RULES =====")
print(spurious_all[['antecedent','consequent','support','confidence','lift','p_value','reason']].head(20).to_string(index=False))
# Out:
# All Rules: 224
#                            antecedent                consequent  support  confidence      lift       p_value
# 0                    frozenset({bag})        frozenset({water})    0.286    0.410330  0.988747  7.004205e-01
# 1                  frozenset({water})          frozenset({bag})    0.286    0.689157  0.988747  7.004205e-01
# 2                    frozenset({bag})         frozenset({rice})    0.273    0.391679  1.041698  1.384957e-01
# 3                   frozenset({rice})          frozenset({bag})    0.273    0.726064  1.041698  1.384957e-01
# 4                    frozenset({bag})         frozenset({milk})    0.216    0.309900  0.971472  3.883358e-01
# ..                                ...                       ...      ...         ...       ...           ...
# 219          frozenset({bag, cereal})  frozenset({water, milk})    0.056    0.434109  3.239616  3.574766e-26
# 220     frozenset({water, milk, bag})       frozenset({cereal})    0.056    0.589474  3.070175  1.935206e-24
# 221  frozenset({water, milk, cereal})          frozenset({bag})    0.056    0.674699  0.968004  7.361379e-01
# 222    frozenset({bag, milk, cereal})        frozenset({water})    0.056    0.434109  1.046045  7.067438e-01
# 223   frozenset({water, cereal, bag})         frozenset({milk})    0.056    1.000000  3.134796  1.174017e-28
#
# [224 rows x 6 columns]
#
# ===== Basic Rules (A) = Support + Confidence =====
#                       antecedent               consequent  support  confidence     lift       p_value
#              frozenset({cereal})        frozenset({milk})    0.192    1.000000 3.134796 1.725405e-111
#               frozenset({bread})        frozenset({milk})    0.129    1.000000 3.134796  5.967343e-70
#         frozenset({bag, cereal})        frozenset({milk})    0.129    1.000000 3.134796  5.967343e-70
#               frozenset({chips})        frozenset({beer})    0.113    1.000000 4.032258  5.139122e-85
#          frozenset({bag, bread})        frozenset({milk})    0.087    1.000000 3.134796  2.081941e-45
#       frozenset({water, cereal})        frozenset({milk})    0.083    1.000000 3.134796  3.476111e-43
#  frozenset({water, cereal, bag})        frozenset({milk})    0.056    1.000000 3.134796  1.174017e-28
#          frozenset({beer, rice})         frozenset({bag})    0.080    0.747664 1.072688  2.733135e-01
#          frozenset({rice, soda})         frozenset({bag})    0.081    0.743119 1.066168  3.175103e-01
#       frozenset({chicken, soda})         frozenset({bag})    0.066    0.741573 1.063950  4.021196e-01
#       frozenset({chicken, rice})         frozenset({bag})    0.088    0.739496 1.060970  3.328167e-01
#          frozenset({milk, rice})         frozenset({bag})    0.079    0.738318 1.059279  3.827428e-01
#                frozenset({rice})         frozenset({bag})    0.273    0.726064 1.041698  1.384957e-01
#       frozenset({milk, chicken})         frozenset({bag})    0.069    0.718750 1.031205  7.106890e-01
#      frozenset({water, chicken})         frozenset({bag})    0.082    0.713043 1.023018  7.717314e-01
#         frozenset({water, rice})         frozenset({bag})    0.113    0.710692 1.019644  7.523272e-01
#         frozenset({water, milk})         frozenset({bag})    0.095    0.708955 1.017152  8.238439e-01
#             frozenset({chicken})         frozenset({bag})    0.209    0.698997 1.002865  9.883677e-01
#                frozenset({beer})         frozenset({bag})    0.173    0.697581 1.000833  1.000000e+00
#                frozenset({soda})         frozenset({bag})    0.211    0.694079 0.995809  9.537141e-01
#      frozenset({chicken, straw})         frozenset({bag})    0.058    0.690476 0.990640  9.904995e-01
#               frozenset({water})         frozenset({bag})    0.286    0.689157 0.988747  7.004205e-01
#        frozenset({water, straw})         frozenset({bag})    0.086    0.688000 0.987088  8.965333e-01
#                frozenset({milk})         frozenset({bag})    0.216    0.677116 0.971472  3.883358e-01
#         frozenset({water, soda})         frozenset({bag})    0.094    0.676259 0.970242  6.355007e-01
#       frozenset({water, cereal})         frozenset({bag})    0.056    0.674699 0.968004  7.361379e-01
#       frozenset({water, cereal})   frozenset({bag, milk})    0.056    0.674699 3.123606  1.245538e-25
# frozenset({water, milk, cereal})         frozenset({bag})    0.056    0.674699 0.968004  7.361379e-01
#               frozenset({bread})         frozenset({bag})    0.087    0.674419 0.967602  6.203502e-01
#               frozenset({bread})   frozenset({bag, milk})    0.087    0.674419 3.122308  3.413767e-41
#         frozenset({milk, bread})         frozenset({bag})    0.087    0.674419 0.967602  6.203502e-01
#              frozenset({cereal})         frozenset({bag})    0.129    0.671875 0.963953  4.499937e-01
#              frozenset({cereal})   frozenset({bag, milk})    0.129    0.671875 3.110532  1.170259e-64
#        frozenset({milk, cereal})         frozenset({bag})    0.129    0.671875 0.963953  4.499937e-01
#         frozenset({straw, rice})         frozenset({bag})    0.079    0.669492 0.960533  5.580660e-01
#          frozenset({milk, soda})         frozenset({bag})    0.065    0.663265 0.951600  5.160592e-01
#         frozenset({water, beer})         frozenset({bag})    0.064    0.659794 0.946620  4.697668e-01
#               frozenset({straw})         frozenset({bag})    0.201    0.659016 0.945504  9.757104e-02
#         frozenset({milk, straw})         frozenset({bag})    0.068    0.641509 0.920387  2.289563e-01
#         frozenset({water, milk})      frozenset({cereal})    0.083    0.619403 3.226057  7.880558e-41
#         frozenset({straw, soda})         frozenset({bag})    0.052    0.619048 0.888160  1.335290e-01
#                frozenset({milk})      frozenset({cereal})    0.192    0.601881 3.134796 1.725405e-111
#           frozenset({bag, milk})      frozenset({cereal})    0.129    0.597222 3.110532  1.170259e-64
#    frozenset({water, milk, bag})      frozenset({cereal})    0.056    0.589474 3.070175  1.935206e-24
#         frozenset({milk, straw})       frozenset({water})    0.052    0.490566 1.182087  1.174124e-01
#           frozenset({bag, beer})        frozenset({rice})    0.080    0.462428 1.229861  1.261706e-02
#          frozenset({rice, soda})       frozenset({water})    0.050    0.458716 1.105339  3.797567e-01
#         frozenset({straw, rice})       frozenset({water})    0.054    0.457627 1.102716  3.674823e-01
#                frozenset({soda})       frozenset({water})    0.139    0.457237 1.101776  8.511361e-02
#                frozenset({beer})       frozenset({chips})    0.113    0.455645 4.032258  5.139122e-85
#           frozenset({bag, soda})       frozenset({water})    0.094    0.445498 1.073488  3.505345e-01
#           frozenset({bag, milk})       frozenset({water})    0.095    0.439815 1.059795  4.484717e-01
#      frozenset({water, chicken})        frozenset({rice})    0.050    0.434783 1.156337  2.001746e-01
#         frozenset({bag, cereal})       frozenset({water})    0.056    0.434109 1.046045  7.067438e-01
#         frozenset({bag, cereal}) frozenset({water, milk})    0.056    0.434109 3.239616  3.574766e-26
#   frozenset({bag, milk, cereal})       frozenset({water})    0.056    0.434109 1.046045  7.067438e-01
#              frozenset({cereal})       frozenset({water})    0.083    0.432292 1.041667  6.458711e-01
#              frozenset({cereal}) frozenset({water, milk})    0.083    0.432292 3.226057  7.880558e-41
#        frozenset({milk, cereal})       frozenset({water})    0.083    0.432292 1.041667  6.458711e-01
#        frozenset({water, straw})        frozenset({rice})    0.054    0.432000 1.148936  1.994492e-01
#                frozenset({beer})        frozenset({rice})    0.107    0.431452 1.147478  4.513794e-02
#          frozenset({bag, straw})       frozenset({water})    0.086    0.427861 1.030990  7.384456e-01
#                frozenset({rice})       frozenset({water})    0.159    0.422872 1.018969  7.444645e-01
#        frozenset({bag, chicken})        frozenset({rice})    0.088    0.421053 1.119821  1.522576e-01
#       frozenset({chicken, rice})       frozenset({water})    0.050    0.420168 1.012453  9.818140e-01
#                frozenset({milk})       frozenset({water})    0.134    0.420063 1.012199  8.779773e-01
#         frozenset({water, milk}) frozenset({bag, cereal})    0.056    0.417910 3.239616  3.574766e-26
#        frozenset({water, straw})        frozenset({milk})    0.052    0.416000 1.304075  1.708508e-02
#           frozenset({bag, rice})       frozenset({water})    0.113    0.413919 0.997396  1.000000e+00
#                 frozenset({bag})       frozenset({water})    0.286    0.410330 0.988747  7.004205e-01
#               frozenset({straw})       frozenset({water})    0.125    0.409836 0.987557  8.808809e-01
#                frozenset({milk})       frozenset({bread})    0.129    0.404389 3.134796  5.967343e-70
#                frozenset({milk}) frozenset({bag, cereal})    0.129    0.404389 3.134796  5.967343e-70
#           frozenset({bag, milk})       frozenset({bread})    0.087    0.402778 3.122308  3.413767e-41
#             frozenset({chicken})        frozenset({rice})    0.119    0.397993 1.058493  3.862506e-01
#          frozenset({bag, water})        frozenset({rice})    0.113    0.395105 1.050811  4.732781e-01
#          frozenset({bag, straw})        frozenset({rice})    0.079    0.393035 1.045305  6.338301e-01
#        frozenset({bag, chicken})       frozenset({water})    0.082    0.392344 0.945408  5.038256e-01
#                 frozenset({bag})        frozenset({rice})    0.273    0.391679 1.041698  1.384957e-01
#                frozenset({beer})       frozenset({water})    0.097    0.391129 0.942480  4.205344e-01
#         frozenset({water, milk})       frozenset({straw})    0.052    0.388060 1.272327  3.209035e-02
#               frozenset({straw})        frozenset({rice})    0.118    0.386885 1.028950  6.892511e-01
#             frozenset({chicken})       frozenset({water})    0.115    0.384615 0.926784  2.287854e-01
#           frozenset({bag, soda})        frozenset({rice})    0.081    0.383886 1.020974  8.522518e-01
#               frozenset({water})        frozenset({rice})    0.159    0.383133 1.018969  7.444645e-01
#           frozenset({bag, beer})       frozenset({water})    0.064    0.369942 0.891427  2.157934e-01
#           frozenset({bag, milk})        frozenset({rice})    0.079    0.365741 0.972715  7.854403e-01
#         frozenset({water, soda})        frozenset({rice})    0.050    0.359712 0.956681  7.392158e-01
#                frozenset({soda})        frozenset({rice})    0.109    0.358553 0.953597  4.953472e-01
#               frozenset({straw})        frozenset({milk})    0.106    0.347541 1.089470  2.266189e-01
#         frozenset({water, rice})       frozenset({straw})    0.054    0.339623 1.113517  3.471761e-01
#          frozenset({bag, straw})        frozenset({milk})    0.068    0.338308 1.060528  5.670463e-01
#                frozenset({milk})        frozenset({rice})    0.107    0.335423 0.892083  8.132836e-02
#               frozenset({water})        frozenset({soda})    0.139    0.334940 1.101776  8.511361e-02
#                frozenset({milk})       frozenset({straw})    0.106    0.332288 1.089470  2.266189e-01
#          frozenset({bag, water})        frozenset({milk})    0.095    0.332168 1.041278  6.238791e-01
#        frozenset({bag, chicken})        frozenset({milk})    0.069    0.330144 1.034933  7.602144e-01
#          frozenset({bag, water})        frozenset({soda})    0.094    0.328671 1.081156  3.185748e-01
#               frozenset({water})        frozenset({milk})    0.134    0.322892 1.012199  8.779773e-01
#                frozenset({beer})   frozenset({bag, rice})    0.080    0.322581 1.181614  5.251566e-02
#                frozenset({soda})        frozenset({milk})    0.098    0.322368 1.010559  9.383932e-01
#           frozenset({bag, rice})     frozenset({chicken})    0.088    0.322344 1.078075  3.625181e-01
#             frozenset({chicken})        frozenset({milk})    0.096    0.321070 1.006490  9.859298e-01
#           frozenset({bag, milk})     frozenset({chicken})    0.069    0.319444 1.068376  5.109885e-01
#                frozenset({rice})     frozenset({chicken})    0.119    0.316489 1.058493  3.862506e-01
#        frozenset({bag, chicken})        frozenset({soda})    0.066    0.315789 1.038781  7.398312e-01
#           frozenset({bag, milk})       frozenset({straw})    0.068    0.314815 1.032180  7.868616e-01
#         frozenset({water, rice})        frozenset({soda})    0.050    0.314465 1.034426  8.267793e-01
#         frozenset({water, rice})     frozenset({chicken})    0.050    0.314465 1.051724  7.113561e-01
#                frozenset({rice})       frozenset({straw})    0.118    0.313830 1.028950  6.892511e-01
#           frozenset({bag, soda})     frozenset({chicken})    0.066    0.312796 1.046141  6.831614e-01
#                 frozenset({bag})        frozenset({milk})    0.216    0.309900 0.971472  3.883358e-01
#                frozenset({soda})  frozenset({bag, water})    0.094    0.309211 1.081156  3.185748e-01
#           frozenset({bag, soda})        frozenset({milk})    0.065    0.308057 0.965696  7.635606e-01
#                frozenset({milk})        frozenset({soda})    0.098    0.307210 1.010559  9.383932e-01
#                 frozenset({bag})        frozenset({soda})    0.211    0.302726 0.995809  9.537141e-01
#               frozenset({water})       frozenset({straw})    0.125    0.301205 0.987557  8.808809e-01
#                frozenset({milk})     frozenset({chicken})    0.096    0.300940 1.006490  9.859298e-01
#           frozenset({bag, milk})        frozenset({soda})    0.065    0.300926 0.989888  9.781424e-01
#          frozenset({bag, water})       frozenset({straw})    0.086    0.300699 0.985899  9.116517e-01
#                frozenset({rice})  frozenset({bag, water})    0.113    0.300532 1.050811  4.732781e-01
#
# ===== Strong / Interesting Rules (B) = (A) + Lift =====
#                      antecedent               consequent  support  confidence     lift       p_value
#              frozenset({chips})        frozenset({beer})    0.113    1.000000 4.032258  5.139122e-85
#               frozenset({beer})       frozenset({chips})    0.113    0.455645 4.032258  5.139122e-85
#        frozenset({water, milk}) frozenset({bag, cereal})    0.056    0.417910 3.239616  3.574766e-26
#        frozenset({bag, cereal}) frozenset({water, milk})    0.056    0.434109 3.239616  3.574766e-26
#        frozenset({water, milk})      frozenset({cereal})    0.083    0.619403 3.226057  7.880558e-41
#             frozenset({cereal}) frozenset({water, milk})    0.083    0.432292 3.226057  7.880558e-41
#             frozenset({cereal})        frozenset({milk})    0.192    1.000000 3.134796 1.725405e-111
#              frozenset({bread})        frozenset({milk})    0.129    1.000000 3.134796  5.967343e-70
#        frozenset({bag, cereal})        frozenset({milk})    0.129    1.000000 3.134796  5.967343e-70
#         frozenset({bag, bread})        frozenset({milk})    0.087    1.000000 3.134796  2.081941e-45
#      frozenset({water, cereal})        frozenset({milk})    0.083    1.000000 3.134796  3.476111e-43
# frozenset({water, cereal, bag})        frozenset({milk})    0.056    1.000000 3.134796  1.174017e-28
#               frozenset({milk})      frozenset({cereal})    0.192    0.601881 3.134796 1.725405e-111
#               frozenset({milk})       frozenset({bread})    0.129    0.404389 3.134796  5.967343e-70
#               frozenset({milk}) frozenset({bag, cereal})    0.129    0.404389 3.134796  5.967343e-70
#      frozenset({water, cereal})   frozenset({bag, milk})    0.056    0.674699 3.123606  1.245538e-25
#              frozenset({bread})   frozenset({bag, milk})    0.087    0.674419 3.122308  3.413767e-41
#          frozenset({bag, milk})       frozenset({bread})    0.087    0.402778 3.122308  3.413767e-41
#             frozenset({cereal})   frozenset({bag, milk})    0.129    0.671875 3.110532  1.170259e-64
#          frozenset({bag, milk})      frozenset({cereal})    0.129    0.597222 3.110532  1.170259e-64
#   frozenset({water, milk, bag})      frozenset({cereal})    0.056    0.589474 3.070175  1.935206e-24
#       frozenset({water, straw})        frozenset({milk})    0.052    0.416000 1.304075  1.708508e-02
#        frozenset({water, milk})       frozenset({straw})    0.052    0.388060 1.272327  3.209035e-02
#          frozenset({bag, beer})        frozenset({rice})    0.080    0.462428 1.229861  1.261706e-02
#        frozenset({milk, straw})       frozenset({water})    0.052    0.490566 1.182087  1.174124e-01
#               frozenset({beer})   frozenset({bag, rice})    0.080    0.322581 1.181614  5.251566e-02
#     frozenset({water, chicken})        frozenset({rice})    0.050    0.434783 1.156337  2.001746e-01
#       frozenset({water, straw})        frozenset({rice})    0.054    0.432000 1.148936  1.994492e-01
#               frozenset({beer})        frozenset({rice})    0.107    0.431452 1.147478  4.513794e-02
#       frozenset({bag, chicken})        frozenset({rice})    0.088    0.421053 1.119821  1.522576e-01
#        frozenset({water, rice})       frozenset({straw})    0.054    0.339623 1.113517  3.471761e-01
#         frozenset({rice, soda})       frozenset({water})    0.050    0.458716 1.105339  3.797567e-01
#        frozenset({straw, rice})       frozenset({water})    0.054    0.457627 1.102716  3.674823e-01
#               frozenset({soda})       frozenset({water})    0.139    0.457237 1.101776  8.511361e-02
#              frozenset({water})        frozenset({soda})    0.139    0.334940 1.101776  8.511361e-02
#              frozenset({straw})        frozenset({milk})    0.106    0.347541 1.089470  2.266189e-01
#               frozenset({milk})       frozenset({straw})    0.106    0.332288 1.089470  2.266189e-01
#         frozenset({bag, water})        frozenset({soda})    0.094    0.328671 1.081156  3.185748e-01
#               frozenset({soda})  frozenset({bag, water})    0.094    0.309211 1.081156  3.185748e-01
#          frozenset({bag, rice})     frozenset({chicken})    0.088    0.322344 1.078075  3.625181e-01
#          frozenset({bag, soda})       frozenset({water})    0.094    0.445498 1.073488  3.505345e-01
#         frozenset({beer, rice})         frozenset({bag})    0.080    0.747664 1.072688  2.733135e-01
#          frozenset({bag, milk})     frozenset({chicken})    0.069    0.319444 1.068376  5.109885e-01
#         frozenset({rice, soda})         frozenset({bag})    0.081    0.743119 1.066168  3.175103e-01
#      frozenset({chicken, soda})         frozenset({bag})    0.066    0.741573 1.063950  4.021196e-01
#      frozenset({chicken, rice})         frozenset({bag})    0.088    0.739496 1.060970  3.328167e-01
#         frozenset({bag, straw})        frozenset({milk})    0.068    0.338308 1.060528  5.670463e-01
#          frozenset({bag, milk})       frozenset({water})    0.095    0.439815 1.059795  4.484717e-01
#         frozenset({milk, rice})         frozenset({bag})    0.079    0.738318 1.059279  3.827428e-01
#            frozenset({chicken})        frozenset({rice})    0.119    0.397993 1.058493  3.862506e-01
#               frozenset({rice})     frozenset({chicken})    0.119    0.316489 1.058493  3.862506e-01
#        frozenset({water, rice})     frozenset({chicken})    0.050    0.314465 1.051724  7.113561e-01
#         frozenset({bag, water})        frozenset({rice})    0.113    0.395105 1.050811  4.732781e-01
#               frozenset({rice})  frozenset({bag, water})    0.113    0.300532 1.050811  4.732781e-01
#          frozenset({bag, soda})     frozenset({chicken})    0.066    0.312796 1.046141  6.831614e-01
#        frozenset({bag, cereal})       frozenset({water})    0.056    0.434109 1.046045  7.067438e-01
#  frozenset({bag, milk, cereal})       frozenset({water})    0.056    0.434109 1.046045  7.067438e-01
#         frozenset({bag, straw})        frozenset({rice})    0.079    0.393035 1.045305  6.338301e-01
#               frozenset({rice})         frozenset({bag})    0.273    0.726064 1.041698  1.384957e-01
#                frozenset({bag})        frozenset({rice})    0.273    0.391679 1.041698  1.384957e-01
#             frozenset({cereal})       frozenset({water})    0.083    0.432292 1.041667  6.458711e-01
#       frozenset({milk, cereal})       frozenset({water})    0.083    0.432292 1.041667  6.458711e-01
#         frozenset({bag, water})        frozenset({milk})    0.095    0.332168 1.041278  6.238791e-01
#       frozenset({bag, chicken})        frozenset({soda})    0.066    0.315789 1.038781  7.398312e-01
#       frozenset({bag, chicken})        frozenset({milk})    0.069    0.330144 1.034933  7.602144e-01
#        frozenset({water, rice})        frozenset({soda})    0.050    0.314465 1.034426  8.267793e-01
#          frozenset({bag, milk})       frozenset({straw})    0.068    0.314815 1.032180  7.868616e-01
#      frozenset({milk, chicken})         frozenset({bag})    0.069    0.718750 1.031205  7.106890e-01
#         frozenset({bag, straw})       frozenset({water})    0.086    0.427861 1.030990  7.384456e-01
#              frozenset({straw})        frozenset({rice})    0.118    0.386885 1.028950  6.892511e-01
#               frozenset({rice})       frozenset({straw})    0.118    0.313830 1.028950  6.892511e-01
#     frozenset({water, chicken})         frozenset({bag})    0.082    0.713043 1.023018  7.717314e-01
#          frozenset({bag, soda})        frozenset({rice})    0.081    0.383886 1.020974  8.522518e-01
#        frozenset({water, rice})         frozenset({bag})    0.113    0.710692 1.019644  7.523272e-01
#               frozenset({rice})       frozenset({water})    0.159    0.422872 1.018969  7.444645e-01
#              frozenset({water})        frozenset({rice})    0.159    0.383133 1.018969  7.444645e-01
#        frozenset({water, milk})         frozenset({bag})    0.095    0.708955 1.017152  8.238439e-01
#      frozenset({chicken, rice})       frozenset({water})    0.050    0.420168 1.012453  9.818140e-01
#               frozenset({milk})       frozenset({water})    0.134    0.420063 1.012199  8.779773e-01
#              frozenset({water})        frozenset({milk})    0.134    0.322892 1.012199  8.779773e-01
#               frozenset({soda})        frozenset({milk})    0.098    0.322368 1.010559  9.383932e-01
#               frozenset({milk})        frozenset({soda})    0.098    0.307210 1.010559  9.383932e-01
#            frozenset({chicken})        frozenset({milk})    0.096    0.321070 1.006490  9.859298e-01
#               frozenset({milk})     frozenset({chicken})    0.096    0.300940 1.006490  9.859298e-01
#            frozenset({chicken})         frozenset({bag})    0.209    0.698997 1.002865  9.883677e-01
#               frozenset({beer})         frozenset({bag})    0.173    0.697581 1.000833  1.000000e+00
#
# ===== Significant Rules (C) = (B) + p-value =====
#                      antecedent               consequent  support  confidence     lift       p_value
#             frozenset({cereal})        frozenset({milk})    0.192    1.000000 3.134796 1.725405e-111
#               frozenset({milk})      frozenset({cereal})    0.192    0.601881 3.134796 1.725405e-111
#              frozenset({chips})        frozenset({beer})    0.113    1.000000 4.032258  5.139122e-85
#               frozenset({beer})       frozenset({chips})    0.113    0.455645 4.032258  5.139122e-85
#              frozenset({bread})        frozenset({milk})    0.129    1.000000 3.134796  5.967343e-70
#        frozenset({bag, cereal})        frozenset({milk})    0.129    1.000000 3.134796  5.967343e-70
#               frozenset({milk})       frozenset({bread})    0.129    0.404389 3.134796  5.967343e-70
#               frozenset({milk}) frozenset({bag, cereal})    0.129    0.404389 3.134796  5.967343e-70
#             frozenset({cereal})   frozenset({bag, milk})    0.129    0.671875 3.110532  1.170259e-64
#          frozenset({bag, milk})      frozenset({cereal})    0.129    0.597222 3.110532  1.170259e-64
#         frozenset({bag, bread})        frozenset({milk})    0.087    1.000000 3.134796  2.081941e-45
#      frozenset({water, cereal})        frozenset({milk})    0.083    1.000000 3.134796  3.476111e-43
#              frozenset({bread})   frozenset({bag, milk})    0.087    0.674419 3.122308  3.413767e-41
#          frozenset({bag, milk})       frozenset({bread})    0.087    0.402778 3.122308  3.413767e-41
#        frozenset({water, milk})      frozenset({cereal})    0.083    0.619403 3.226057  7.880558e-41
#             frozenset({cereal}) frozenset({water, milk})    0.083    0.432292 3.226057  7.880558e-41
# frozenset({water, cereal, bag})        frozenset({milk})    0.056    1.000000 3.134796  1.174017e-28
#        frozenset({water, milk}) frozenset({bag, cereal})    0.056    0.417910 3.239616  3.574766e-26
#        frozenset({bag, cereal}) frozenset({water, milk})    0.056    0.434109 3.239616  3.574766e-26
#      frozenset({water, cereal})   frozenset({bag, milk})    0.056    0.674699 3.123606  1.245538e-25
#   frozenset({water, milk, bag})      frozenset({cereal})    0.056    0.589474 3.070175  1.935206e-24
#          frozenset({bag, beer})        frozenset({rice})    0.080    0.462428 1.229861  1.261706e-02
#       frozenset({water, straw})        frozenset({milk})    0.052    0.416000 1.304075  1.708508e-02
#        frozenset({water, milk})       frozenset({straw})    0.052    0.388060 1.272327  3.209035e-02
#               frozenset({beer})        frozenset({rice})    0.107    0.431452 1.147478  4.513794e-02
#
# COUNT COMPARISON
# (A) Support & Cofidence : 121 rules
# (B) Support, Confidence & Lift : 86 rules
# (C) Support, Confidence, Lift & p-value : 25 rules
#
# 🔴 Spurious Rules removed in Step B (Lift filter)
#                  antecedent         consequent  support  confidence     lift  p_value                            reason
#      frozenset({bag, rice}) frozenset({water})    0.113    0.413919 0.997396 1.000000      Low Lift (<=1) → Independent
#           frozenset({soda})   frozenset({bag})    0.211    0.694079 0.995809 0.953714      Low Lift (<=1) → Independent
#            frozenset({bag})  frozenset({soda})    0.211    0.302726 0.995809 0.953714      Low Lift (<=1) → Independent
# frozenset({chicken, straw})   frozenset({bag})    0.058    0.690476 0.990640 0.990500      Low Lift (<=1) → Independent
#      frozenset({bag, milk})  frozenset({soda})    0.065    0.300926 0.989888 0.978142      Low Lift (<=1) → Independent
#            frozenset({bag}) frozenset({water})    0.286    0.410330 0.988747 0.700420      Low Lift (<=1) → Independent
#          frozenset({water})   frozenset({bag})    0.286    0.689157 0.988747 0.700420      Low Lift (<=1) → Independent
#          frozenset({water}) frozenset({straw})    0.125    0.301205 0.987557 0.880881      Low Lift (<=1) → Independent
#          frozenset({straw}) frozenset({water})    0.125    0.409836 0.987557 0.880881      Low Lift (<=1) → Independent
#   frozenset({water, straw})   frozenset({bag})    0.086    0.688000 0.987088 0.896533      Low Lift (<=1) → Independent
#
# 🔴 Spurious Rules removed in Step C (p-value filter)
#                  antecedent             consequent  support  confidence     lift  p_value                                       reason
#           frozenset({beer}) frozenset({bag, rice})    0.080    0.322581 1.181614 0.052516      High p-value (>=0.05) → Not Significant
#           frozenset({soda})     frozenset({water})    0.139    0.457237 1.101776 0.085114      High p-value (>=0.05) → Not Significant
#          frozenset({water})      frozenset({soda})    0.139    0.334940 1.101776 0.085114      High p-value (>=0.05) → Not Significant
#    frozenset({milk, straw})     frozenset({water})    0.052    0.490566 1.182087 0.117412      High p-value (>=0.05) → Not Significant
#            frozenset({bag})      frozenset({rice})    0.273    0.391679 1.041698 0.138496      High p-value (>=0.05) → Not Significant
#           frozenset({rice})       frozenset({bag})    0.273    0.726064 1.041698 0.138496      High p-value (>=0.05) → Not Significant
#   frozenset({bag, chicken})      frozenset({rice})    0.088    0.421053 1.119821 0.152258      High p-value (>=0.05) → Not Significant
#   frozenset({water, straw})      frozenset({rice})    0.054    0.432000 1.148936 0.199449      High p-value (>=0.05) → Not Significant
# frozenset({water, chicken})      frozenset({rice})    0.050    0.434783 1.156337 0.200175      High p-value (>=0.05) → Not Significant
#          frozenset({straw})      frozenset({milk})    0.106    0.347541 1.089470 0.226619      High p-value (>=0.05) → Not Significant
#
# ===== SUMMARY OF SPURIOUS RULES =====
#                       antecedent         consequent  support  confidence     lift  p_value                            reason
#                frozenset({soda})   frozenset({bag})    0.211    0.694079 0.995809 0.953714      Low Lift (<=1) → Independent
#      frozenset({chicken, straw})   frozenset({bag})    0.058    0.690476 0.990640 0.990500      Low Lift (<=1) → Independent
#               frozenset({water})   frozenset({bag})    0.286    0.689157 0.988747 0.700420      Low Lift (<=1) → Independent
#        frozenset({water, straw})   frozenset({bag})    0.086    0.688000 0.987088 0.896533      Low Lift (<=1) → Independent
#                frozenset({milk})   frozenset({bag})    0.216    0.677116 0.971472 0.388336      Low Lift (<=1) → Independent
#         frozenset({water, soda})   frozenset({bag})    0.094    0.676259 0.970242 0.635501      Low Lift (<=1) → Independent
#       frozenset({water, cereal})   frozenset({bag})    0.056    0.674699 0.968004 0.736138      Low Lift (<=1) → Independent
# frozenset({water, milk, cereal})   frozenset({bag})    0.056    0.674699 0.968004 0.736138      Low Lift (<=1) → Independent
#               frozenset({bread})   frozenset({bag})    0.087    0.674419 0.967602 0.620350      Low Lift (<=1) → Independent
#         frozenset({milk, bread})   frozenset({bag})    0.087    0.674419 0.967602 0.620350      Low Lift (<=1) → Independent
#              frozenset({cereal})   frozenset({bag})    0.129    0.671875 0.963953 0.449994      Low Lift (<=1) → Independent
#        frozenset({milk, cereal})   frozenset({bag})    0.129    0.671875 0.963953 0.449994      Low Lift (<=1) → Independent
#         frozenset({straw, rice})   frozenset({bag})    0.079    0.669492 0.960533 0.558066      Low Lift (<=1) → Independent
#          frozenset({milk, soda})   frozenset({bag})    0.065    0.663265 0.951600 0.516059      Low Lift (<=1) → Independent
#         frozenset({water, beer})   frozenset({bag})    0.064    0.659794 0.946620 0.469767      Low Lift (<=1) → Independent
#               frozenset({straw})   frozenset({bag})    0.201    0.659016 0.945504 0.097571      Low Lift (<=1) → Independent
#         frozenset({milk, straw})   frozenset({bag})    0.068    0.641509 0.920387 0.228956      Low Lift (<=1) → Independent
#         frozenset({straw, soda})   frozenset({bag})    0.052    0.619048 0.888160 0.133529      Low Lift (<=1) → Independent
#           frozenset({bag, rice}) frozenset({water})    0.113    0.413919 0.997396 1.000000      Low Lift (<=1) → Independent
#                 frozenset({bag}) frozenset({water})    0.286    0.410330 0.988747 0.700420      Low Lift (<=1) → Independent
